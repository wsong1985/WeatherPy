# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'City Count: {len(cities)}')
# Out:
# City Count: 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

from pprint import pprint

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | la roche-sur-yon
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 1 | torbay
# Processing Record 6 of Set 1 | saint-philippe
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | artyk
# City not found. Skipping...
# Processing Record 9 of Set 1 | mocuba
# Processing Record 10 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | faanui
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | jacqueville
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | cockburn town
# Processing Record 18 of Set 1 | yeppoon
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | leningradskiy
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | kahului
# Processing Record 24 of Set 1 | north guwahati
# Processing Record 25 of Set 1 | ballina
# Processing Record 26 of Set 1 | nueve de julio
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | the valley
# Processing Record 29 of Set 1 | ilulissat
# Processing Record 30 of Set 1 | tahta
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | shieli
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | barrow
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 38 of Set 1 | camana
# Processing Record 39 of Set 1 | ponta do sol
# Processing Record 40 of Set 1 | mehamn
# Processing Record 41 of Set 1 | port hardy
# Processing Record 42 of Set 1 | tepla
# Processing Record 43 of Set 1 | price
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | staveley
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 49 of Set 1 | tres lagoas
# Processing Record 50 of Set 1 | natal
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | bambanglipuro
# Processing Record 6 of Set 2 | vaini
# Processing Record 7 of Set 2 | maine-soroa
# Processing Record 8 of Set 2 | banda aceh
# Processing Record 9 of Set 2 | zhoucun
# Processing Record 10 of Set 2 | geraldton
# Processing Record 11 of Set 2 | poya
# Processing Record 12 of Set 2 | okha
# Processing Record 13 of Set 2 | rawson
# Processing Record 14 of Set 2 | bambous virieux
# Processing Record 15 of Set 2 | ribeira grande
# Processing Record 16 of Set 2 | tabukiniberu
# City not found. Skipping...
# Processing Record 17 of Set 2 | duzce
# Processing Record 18 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 19 of Set 2 | dabat
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | tocopilla
# Processing Record 22 of Set 2 | taoudenni
# Processing Record 23 of Set 2 | erechim
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | jiayuguan
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | lompoc
# Processing Record 28 of Set 2 | bathsheba
# Processing Record 29 of Set 2 | maneadero
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | ayan
# Processing Record 32 of Set 2 | pisco
# Processing Record 33 of Set 2 | hammerfest
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | bilma
# Processing Record 36 of Set 2 | hun
# Processing Record 37 of Set 2 | khasan
# Processing Record 38 of Set 2 | norman wells
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | rocha
# Processing Record 42 of Set 2 | naze
# Processing Record 43 of Set 2 | yar-sale
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | hondo
# Processing Record 46 of Set 2 | buala
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | hauterive
# Processing Record 49 of Set 2 | asau
# Processing Record 50 of Set 2 | ituni
# City not found. Skipping...
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | walvis bay
# Processing Record 3 of Set 3 | calamar
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | hithadhoo
# Processing Record 6 of Set 3 | west helena
# Processing Record 7 of Set 3 | bowen
# Processing Record 8 of Set 3 | boende
# Processing Record 9 of Set 3 | angra
# City not found. Skipping...
# Processing Record 10 of Set 3 | puerto del rosario
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | bonanza
# Processing Record 15 of Set 3 | lubango
# Processing Record 16 of Set 3 | nantucket
# Processing Record 17 of Set 3 | koungou
# Processing Record 18 of Set 3 | severo-kurilsk
# Processing Record 19 of Set 3 | kudahuvadhoo
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | padang
# Processing Record 22 of Set 3 | avarua
# Processing Record 23 of Set 3 | san jeronimo
# Processing Record 24 of Set 3 | russell
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | portland
# Processing Record 27 of Set 3 | surin
# Processing Record 28 of Set 3 | coruripe
# Processing Record 29 of Set 3 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 3 | port hedland
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | ancud
# Processing Record 33 of Set 3 | port blair
# Processing Record 34 of Set 3 | xining
# Processing Record 35 of Set 3 | elliot lake
# Processing Record 36 of Set 3 | tura
# Processing Record 37 of Set 3 | paamiut
# Processing Record 38 of Set 3 | chuy
# Processing Record 39 of Set 3 | yarmouth
# Processing Record 40 of Set 3 | saint george
# Processing Record 41 of Set 3 | shahr-e babak
# Processing Record 42 of Set 3 | kuvshinovo
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | kirakira
# Processing Record 45 of Set 3 | katsuura
# Processing Record 46 of Set 3 | chokurdakh
# Processing Record 47 of Set 3 | terrace bay
# Processing Record 48 of Set 3 | yola
# Processing Record 49 of Set 3 | provideniya
# Processing Record 50 of Set 3 | lagoa
# Processing Record 1 of Set 4 | beringovskiy
# Processing Record 2 of Set 4 | yulara
# Processing Record 3 of Set 4 | great bend
# Processing Record 4 of Set 4 | maniitsoq
# Processing Record 5 of Set 4 | zyryanskoye
# Processing Record 6 of Set 4 | gravelbourg
# Processing Record 7 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 4 | pangody
# Processing Record 9 of Set 4 | port elizabeth
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | hambantota
# Processing Record 12 of Set 4 | veraval
# Processing Record 13 of Set 4 | pietrosani
# Processing Record 14 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 15 of Set 4 | kendari
# Processing Record 16 of Set 4 | puerto escondido
# Processing Record 17 of Set 4 | hay river
# Processing Record 18 of Set 4 | glendive
# Processing Record 19 of Set 4 | kavieng
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | sao filipe
# Processing Record 22 of Set 4 | narsaq
# Processing Record 23 of Set 4 | constitucion
# Processing Record 24 of Set 4 | ouesso
# Processing Record 25 of Set 4 | rezina
# Processing Record 26 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 4 | narsipatnam
# Processing Record 28 of Set 4 | de-kastri
# Processing Record 29 of Set 4 | port alfred
# Processing Record 30 of Set 4 | isla mujeres
# Processing Record 31 of Set 4 | hilo
# Processing Record 32 of Set 4 | kelso
# Processing Record 33 of Set 4 | mizdah
# Processing Record 34 of Set 4 | gizo
# Processing Record 35 of Set 4 | adjumani
# Processing Record 36 of Set 4 | flinders
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | tabuk
# Processing Record 39 of Set 4 | bekovo
# Processing Record 40 of Set 4 | san rafael del sur
# Processing Record 41 of Set 4 | fortuna
# Processing Record 42 of Set 4 | sitka
# Processing Record 43 of Set 4 | touros
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | kroonstad
# Processing Record 46 of Set 4 | cap-aux-meules
# Processing Record 47 of Set 4 | port macquarie
# Processing Record 48 of Set 4 | kodiak
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | stilfontein
# Processing Record 2 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 5 | littleton
# Processing Record 4 of Set 5 | izhma
# Processing Record 5 of Set 5 | sola
# Processing Record 6 of Set 5 | kaitangata
# Processing Record 7 of Set 5 | buta
# Processing Record 8 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 5 | koslan
# Processing Record 10 of Set 5 | chabahar
# Processing Record 11 of Set 5 | college
# Processing Record 12 of Set 5 | hofn
# Processing Record 13 of Set 5 | sisimiut
# Processing Record 14 of Set 5 | namibe
# Processing Record 15 of Set 5 | ostrovnoy
# Processing Record 16 of Set 5 | zuenoula
# Processing Record 17 of Set 5 | kyaikkami
# Processing Record 18 of Set 5 | tecoanapa
# Processing Record 19 of Set 5 | airai
# Processing Record 20 of Set 5 | talcahuano
# Processing Record 21 of Set 5 | gat
# Processing Record 22 of Set 5 | adre
# Processing Record 23 of Set 5 | rampura
# Processing Record 24 of Set 5 | ha tinh
# Processing Record 25 of Set 5 | mankono
# Processing Record 26 of Set 5 | shepsi
# Processing Record 27 of Set 5 | ranaghat
# Processing Record 28 of Set 5 | saint-augustin
# Processing Record 29 of Set 5 | cidreira
# Processing Record 30 of Set 5 | le pradet
# Processing Record 31 of Set 5 | kidal
# Processing Record 32 of Set 5 | scarborough
# Processing Record 33 of Set 5 | mahebourg
# Processing Record 34 of Set 5 | sabha
# Processing Record 35 of Set 5 | waipawa
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | tautira
# Processing Record 38 of Set 5 | tuatapere
# Processing Record 39 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 5 | villa de cura
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | san vicente
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | yuanping
# Processing Record 45 of Set 5 | nikolskoye
# Processing Record 46 of Set 5 | namtsy
# Processing Record 47 of Set 5 | ridgecrest
# Processing Record 48 of Set 5 | hohhot
# Processing Record 49 of Set 5 | springdale
# Processing Record 50 of Set 5 | jining
# Processing Record 1 of Set 6 | pevek
# Processing Record 2 of Set 6 | brae
# Processing Record 3 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 6 | ede
# Processing Record 5 of Set 6 | palauig
# Processing Record 6 of Set 6 | naifaru
# Processing Record 7 of Set 6 | inuvik
# Processing Record 8 of Set 6 | looc
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | tornio
# Processing Record 11 of Set 6 | port-gentil
# Processing Record 12 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 6 | hvide sande
# Processing Record 14 of Set 6 | staraya russa
# Processing Record 15 of Set 6 | grants
# Processing Record 16 of Set 6 | guerrero negro
# Processing Record 17 of Set 6 | frutal
# Processing Record 18 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 19 of Set 6 | takoradi
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | werda
# Processing Record 22 of Set 6 | namatanai
# Processing Record 23 of Set 6 | krasnoselkup
# Processing Record 24 of Set 6 | basoko
# Processing Record 25 of Set 6 | healesville
# Processing Record 26 of Set 6 | makakilo city
# Processing Record 27 of Set 6 | sarab
# Processing Record 28 of Set 6 | ascension
# Processing Record 29 of Set 6 | dalby
# Processing Record 30 of Set 6 | salalah
# Processing Record 31 of Set 6 | la cruz
# Processing Record 32 of Set 6 | dali
# Processing Record 33 of Set 6 | san felipe
# Processing Record 34 of Set 6 | druzhba
# Processing Record 35 of Set 6 | coahuayana
# Processing Record 36 of Set 6 | xuanhua
# Processing Record 37 of Set 6 | pierre
# Processing Record 38 of Set 6 | summerville
# Processing Record 39 of Set 6 | frederico westphalen
# Processing Record 40 of Set 6 | passy
# Processing Record 41 of Set 6 | kulhudhuffushi
# Processing Record 42 of Set 6 | clyde river
# Processing Record 43 of Set 6 | biryusinsk
# Processing Record 44 of Set 6 | cayambe
# Processing Record 45 of Set 6 | vila do maio
# Processing Record 46 of Set 6 | idritsa
# Processing Record 47 of Set 6 | saint-louis
# Processing Record 48 of Set 6 | hervey bay
# Processing Record 49 of Set 6 | ugoofaaru
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | harnosand
# Processing Record 3 of Set 7 | diego de almagro
# Processing Record 4 of Set 7 | bhadrachalam
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 7 of Set 7 | nara
# Processing Record 8 of Set 7 | simao dias
# Processing Record 9 of Set 7 | marawi
# Processing Record 10 of Set 7 | vanavara
# Processing Record 11 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 12 of Set 7 | meadow lake
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 7 | kruisfontein
# Processing Record 16 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 17 of Set 7 | kouango
# Processing Record 18 of Set 7 | kingaroy
# Processing Record 19 of Set 7 | lagunas
# Processing Record 20 of Set 7 | alofi
# Processing Record 21 of Set 7 | sobolevo
# Processing Record 22 of Set 7 | tamiahua
# Processing Record 23 of Set 7 | saldanha
# Processing Record 24 of Set 7 | rio grande
# Processing Record 25 of Set 7 | les escoumins
# Processing Record 26 of Set 7 | coihaique
# Processing Record 27 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 7 | gilgit
# Processing Record 29 of Set 7 | syktyvkar
# Processing Record 30 of Set 7 | tiarei
# Processing Record 31 of Set 7 | tilichiki
# Processing Record 32 of Set 7 | baykit
# Processing Record 33 of Set 7 | san-pedro
# Processing Record 34 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 7 | ambon
# Processing Record 36 of Set 7 | constantine
# Processing Record 37 of Set 7 | la ronge
# Processing Record 38 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 7 | miraflores
# Processing Record 40 of Set 7 | ordynskoye
# Processing Record 41 of Set 7 | itarema
# Processing Record 42 of Set 7 | peterhead
# Processing Record 43 of Set 7 | talnakh
# Processing Record 44 of Set 7 | labuhan
# Processing Record 45 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 7 | batagay-alyta
# Processing Record 47 of Set 7 | lazaro cardenas
# Processing Record 48 of Set 7 | urucurituba
# Processing Record 49 of Set 7 | haines junction
# Processing Record 50 of Set 7 | hasaki
# Processing Record 1 of Set 8 | ceres
# Processing Record 2 of Set 8 | nukus
# Processing Record 3 of Set 8 | kamogawa
# Processing Record 4 of Set 8 | fuyang
# Processing Record 5 of Set 8 | syracuse
# Processing Record 6 of Set 8 | tsaratanana
# Processing Record 7 of Set 8 | pavilosta
# Processing Record 8 of Set 8 | nieuw nickerie
# Processing Record 9 of Set 8 | novikovo
# Processing Record 10 of Set 8 | la palma
# Processing Record 11 of Set 8 | toora-khem
# Processing Record 12 of Set 8 | hami
# Processing Record 13 of Set 8 | aksarka
# Processing Record 14 of Set 8 | henties bay
# Processing Record 15 of Set 8 | wanning
# Processing Record 16 of Set 8 | victoria
# Processing Record 17 of Set 8 | karratha
# Processing Record 18 of Set 8 | merauke
# Processing Record 19 of Set 8 | iguape
# Processing Record 20 of Set 8 | allapalli
# Processing Record 21 of Set 8 | aswan
# Processing Record 22 of Set 8 | te anau
# Processing Record 23 of Set 8 | ponnani
# Processing Record 24 of Set 8 | coffs harbour
# Processing Record 25 of Set 8 | jalu
# Processing Record 26 of Set 8 | puiesti
# Processing Record 27 of Set 8 | broome
# Processing Record 28 of Set 8 | gamba
# Processing Record 29 of Set 8 | taitung
# Processing Record 30 of Set 8 | lavrentiya
# Processing Record 31 of Set 8 | shreveport
# Processing Record 32 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 8 | eureka
# Processing Record 34 of Set 8 | husavik
# Processing Record 35 of Set 8 | rio gallegos
# Processing Record 36 of Set 8 | sao felix do xingu
# Processing Record 37 of Set 8 | najran
# Processing Record 38 of Set 8 | lac du bonnet
# Processing Record 39 of Set 8 | osakarovka
# Processing Record 40 of Set 8 | upernavik
# Processing Record 41 of Set 8 | shimanovsk
# Processing Record 42 of Set 8 | noumea
# Processing Record 43 of Set 8 | san cristobal
# Processing Record 44 of Set 8 | lagos
# Processing Record 45 of Set 8 | mareeba
# Processing Record 46 of Set 8 | herat
# Processing Record 47 of Set 8 | glasgow
# Processing Record 48 of Set 8 | san carlos de bariloche
# Processing Record 49 of Set 8 | los llanos de aridane
# Processing Record 50 of Set 8 | vardo
# Processing Record 1 of Set 9 | sept-iles
# Processing Record 2 of Set 9 | rundu
# Processing Record 3 of Set 9 | half moon bay
# Processing Record 4 of Set 9 | nago
# Processing Record 5 of Set 9 | evensk
# Processing Record 6 of Set 9 | licheng
# Processing Record 7 of Set 9 | nizwa
# Processing Record 8 of Set 9 | dingle
# Processing Record 9 of Set 9 | puerto ayacucho
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | monster
# Processing Record 12 of Set 9 | charagua
# Processing Record 13 of Set 9 | kattivakkam
# Processing Record 14 of Set 9 | minot
# Processing Record 15 of Set 9 | lata
# Processing Record 16 of Set 9 | burkhala
# City not found. Skipping...
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 9 | acapulco
# Processing Record 20 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | tondano
# Processing Record 22 of Set 9 | longyearbyen
# Processing Record 23 of Set 9 | samarinda
# Processing Record 24 of Set 9 | iqaluit
# Processing Record 25 of Set 9 | rantauprapat
# Processing Record 26 of Set 9 | chumikan
# Processing Record 27 of Set 9 | richards bay
# Processing Record 28 of Set 9 | bitung
# Processing Record 29 of Set 9 | keti bandar
# Processing Record 30 of Set 9 | xuddur
# Processing Record 31 of Set 9 | hailar
# Processing Record 32 of Set 9 | praya
# Processing Record 33 of Set 9 | zhanaozen
# Processing Record 34 of Set 9 | oriximina
# Processing Record 35 of Set 9 | hovd
# Processing Record 36 of Set 9 | lethem
# Processing Record 37 of Set 9 | teya
# Processing Record 38 of Set 9 | jinan
# Processing Record 39 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 40 of Set 9 | ipubi
# Processing Record 41 of Set 9 | ixtapa
# Processing Record 42 of Set 9 | carballo
# Processing Record 43 of Set 9 | bisho
# Processing Record 44 of Set 9 | maraba
# Processing Record 45 of Set 9 | adrar
# Processing Record 46 of Set 9 | ulkan
# Processing Record 47 of Set 9 | diamantino
# Processing Record 48 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 9 | vestmannaeyjar
# Processing Record 50 of Set 9 | jeremie
# Processing Record 1 of Set 10 | nang rong
# Processing Record 2 of Set 10 | marrakesh
# Processing Record 3 of Set 10 | yarada
# Processing Record 4 of Set 10 | washington
# Processing Record 5 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 10 | aiquile
# Processing Record 7 of Set 10 | sambava
# Processing Record 8 of Set 10 | severomorsk
# Processing Record 9 of Set 10 | belchatow
# Processing Record 10 of Set 10 | emerald
# Processing Record 11 of Set 10 | moissala
# Processing Record 12 of Set 10 | rorvik
# Processing Record 13 of Set 10 | korla
# Processing Record 14 of Set 10 | cartagena
# Processing Record 15 of Set 10 | meulaboh
# Processing Record 16 of Set 10 | matagami
# Processing Record 17 of Set 10 | morwell
# Processing Record 18 of Set 10 | ramsar
# Processing Record 19 of Set 10 | bend
# Processing Record 20 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 21 of Set 10 | gimli
# Processing Record 22 of Set 10 | raahe
# Processing Record 23 of Set 10 | ahuimanu
# Processing Record 24 of Set 10 | vrangel
# Processing Record 25 of Set 10 | hvolsvollur
# Processing Record 26 of Set 10 | west bay
# Processing Record 27 of Set 10 | shumskiy
# Processing Record 28 of Set 10 | kysyl-syr
# Processing Record 29 of Set 10 | pokhara
# Processing Record 30 of Set 10 | viedma
# Processing Record 31 of Set 10 | konstantinovka
# Processing Record 32 of Set 10 | glace bay
# Processing Record 33 of Set 10 | katobu
# Processing Record 34 of Set 10 | grand gaube
# Processing Record 35 of Set 10 | waingapu
# Processing Record 36 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 37 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 10 | chara
# Processing Record 39 of Set 10 | bubaque
# Processing Record 40 of Set 10 | honiara
# Processing Record 41 of Set 10 | mogadishu
# Processing Record 42 of Set 10 | zabid
# Processing Record 43 of Set 10 | camacupa
# Processing Record 44 of Set 10 | senneterre
# Processing Record 45 of Set 10 | sampit
# Processing Record 46 of Set 10 | huron
# Processing Record 47 of Set 10 | sinnamary
# Processing Record 48 of Set 10 | kenai
# Processing Record 49 of Set 10 | minas de barroteran
# Processing Record 50 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 11 | galesong
# Processing Record 2 of Set 11 | muyezerskiy
# Processing Record 3 of Set 11 | valparaiso
# Processing Record 4 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 11 | de aar
# Processing Record 6 of Set 11 | tiruttani
# Processing Record 7 of Set 11 | dinguiraye
# Processing Record 8 of Set 11 | lai
# Processing Record 9 of Set 11 | palana
# Processing Record 10 of Set 11 | alihe
# Processing Record 11 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 11 | halifax
# Processing Record 13 of Set 11 | aguimes
# Processing Record 14 of Set 11 | zhigansk
# Processing Record 15 of Set 11 | tsabong
# Processing Record 16 of Set 11 | ventspils
# Processing Record 17 of Set 11 | vanimo
# Processing Record 18 of Set 11 | brownwood
# Processing Record 19 of Set 11 | camacha
# Processing Record 20 of Set 11 | nong kung si
# Processing Record 21 of Set 11 | urengoy
# Processing Record 22 of Set 11 | chapais
# Processing Record 23 of Set 11 | chumphon
# Processing Record 24 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 11 | guiyang
# Processing Record 26 of Set 11 | margate
# Processing Record 27 of Set 11 | copiapo
# Processing Record 28 of Set 11 | zhangjiakou
# Processing Record 29 of Set 11 | hellin
# Processing Record 30 of Set 11 | am timan
# Processing Record 31 of Set 11 | paytug
# City not found. Skipping...
# Processing Record 32 of Set 11 | esperance
# Processing Record 33 of Set 11 | kamaishi
# Processing Record 34 of Set 11 | bajil
# Processing Record 35 of Set 11 | verkhnyaya inta
# Processing Record 36 of Set 11 | lilongwe
# Processing Record 37 of Set 11 | nioro
# Processing Record 38 of Set 11 | glencoe
# Processing Record 39 of Set 11 | san policarpo
# Processing Record 40 of Set 11 | jaisinghnagar
# Processing Record 41 of Set 11 | san francisco
# Processing Record 42 of Set 11 | manado
# Processing Record 43 of Set 11 | khandyga
# Processing Record 44 of Set 11 | birjand
# Processing Record 45 of Set 11 | vuktyl
# Processing Record 46 of Set 11 | moree
# Processing Record 47 of Set 11 | san patricio
# Processing Record 48 of Set 11 | xai-xai
# Processing Record 49 of Set 11 | pathein
# Processing Record 50 of Set 11 | lincoln
# Processing Record 1 of Set 12 | mount gambier
# Processing Record 2 of Set 12 | zyryanka
# Processing Record 3 of Set 12 | barsovo
# Processing Record 4 of Set 12 | vila
# Processing Record 5 of Set 12 | lake city
# Processing Record 6 of Set 12 | bac lieu
# Processing Record 7 of Set 12 | sechura
# Processing Record 8 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 9 of Set 12 | baghdad
# Processing Record 10 of Set 12 | lumphat
# Processing Record 11 of Set 12 | havoysund
# Processing Record 12 of Set 12 | gazojak
# Processing Record 13 of Set 12 | marevo
# Processing Record 14 of Set 12 | moron
# Processing Record 15 of Set 12 | yeniseysk
# Processing Record 16 of Set 12 | teguldet
# Processing Record 17 of Set 12 | sarkand
# Processing Record 18 of Set 12 | flin flon
# Processing Record 19 of Set 12 | mayo
# Processing Record 20 of Set 12 | kailua
# Processing Record 21 of Set 12 | zlobin
# Processing Record 22 of Set 12 | grafton
# Processing Record 23 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 12 | unai
# Processing Record 26 of Set 12 | nome
# Processing Record 27 of Set 12 | beloha
# Processing Record 28 of Set 12 | sibolga
# Processing Record 29 of Set 12 | calvinia
# Processing Record 30 of Set 12 | wilmington
# Processing Record 31 of Set 12 | kaka
# Processing Record 32 of Set 12 | kostomuksha
# Processing Record 33 of Set 12 | oga
# Processing Record 34 of Set 12 | castanos
# Processing Record 35 of Set 12 | taltal
# Processing Record 36 of Set 12 | puerto leguizamo
# Processing Record 37 of Set 12 | ossora
# Processing Record 38 of Set 12 | bainbridge
# Processing Record 39 of Set 12 | pasni
# Processing Record 40 of Set 12 | palmas bellas
# Processing Record 41 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 12 | bonnyville
# Processing Record 43 of Set 12 | bilibino
# Processing Record 44 of Set 12 | praxedis guerrero
# Processing Record 45 of Set 12 | chute-aux-outardes
# Processing Record 46 of Set 12 | launceston
# Processing Record 47 of Set 12 | anadyr
# Processing Record 48 of Set 12 | bahia blanca
# Processing Record 49 of Set 12 | urumqi
# Processing Record 50 of Set 12 | pacific grove
# Processing Record 1 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 2 of Set 13 | bandarbeyla
# Processing Record 3 of Set 13 | lasa
# Processing Record 4 of Set 13 | cap malheureux
# Processing Record 5 of Set 13 | gravdal
# Processing Record 6 of Set 13 | esil
# Processing Record 7 of Set 13 | virginia beach
# Processing Record 8 of Set 13 | raga
# Processing Record 9 of Set 13 | sioux lookout
# Processing Record 10 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 11 of Set 13 | diffa
# Processing Record 12 of Set 13 | awjilah
# Processing Record 13 of Set 13 | ternate
# Processing Record 14 of Set 13 | vila velha
# Processing Record 15 of Set 13 | kota belud
# Processing Record 16 of Set 13 | ilo
# Processing Record 17 of Set 13 | manitouwadge
# Processing Record 18 of Set 13 | batemans bay
# Processing Record 19 of Set 13 | solnechnyy
# Processing Record 20 of Set 13 | magadan
# Processing Record 21 of Set 13 | waw
# Processing Record 22 of Set 13 | voh
# Processing Record 23 of Set 13 | thinadhoo
# Processing Record 24 of Set 13 | saint-pierre
# Processing Record 25 of Set 13 | fenoarivo
# Processing Record 26 of Set 13 | teguise
# Processing Record 27 of Set 13 | talmenka
# Processing Record 28 of Set 13 | thabazimbi
# Processing Record 29 of Set 13 | corrente
# Processing Record 30 of Set 13 | mount isa
# Processing Record 31 of Set 13 | dolores
# Processing Record 32 of Set 13 | port-cartier
# Processing Record 33 of Set 13 | svetlaya
# Processing Record 34 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 13 | claveria
# Processing Record 36 of Set 13 | suileng
# Processing Record 37 of Set 13 | porto novo
# Processing Record 38 of Set 13 | havre-saint-pierre
# Processing Record 39 of Set 13 | faya
# Processing Record 40 of Set 13 | vao
# Processing Record 41 of Set 13 | hobyo
# Processing Record 42 of Set 13 | sangar
# Processing Record 43 of Set 13 | acoyapa
# Processing Record 44 of Set 13 | nosy varika
# Processing Record 45 of Set 13 | ambilobe
# Processing Record 46 of Set 13 | shache
# Processing Record 47 of Set 13 | grenaa
# Processing Record 48 of Set 13 | dauriya
# Processing Record 49 of Set 13 | goderich
# Processing Record 50 of Set 13 | biltine
# Processing Record 1 of Set 14 | sankt florian
# Processing Record 2 of Set 14 | andenes
# Processing Record 3 of Set 14 | mitu
# Processing Record 4 of Set 14 | luanda
# Processing Record 5 of Set 14 | trinidad
# Processing Record 6 of Set 14 | oksfjord
# Processing Record 7 of Set 14 | hella
# Processing Record 8 of Set 14 | martinsburg
# Processing Record 9 of Set 14 | lososina
# Processing Record 10 of Set 14 | evanston
# Processing Record 11 of Set 14 | tonder
# Processing Record 12 of Set 14 | alta floresta
# Processing Record 13 of Set 14 | tombouctou
# Processing Record 14 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 14 | morden
# Processing Record 16 of Set 14 | burley
# Processing Record 17 of Set 14 | ratnagiri
# Processing Record 18 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 19 of Set 14 | bima
# Processing Record 20 of Set 14 | surt
# Processing Record 21 of Set 14 | pinhao
# Processing Record 22 of Set 14 | asfi
# Processing Record 23 of Set 14 | huarmey
# Processing Record 24 of Set 14 | wencheng
# Processing Record 25 of Set 14 | dhidhdhoo
# Processing Record 26 of Set 14 | pontal do parana
# Processing Record 27 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 14 | ler
# Processing Record 29 of Set 14 | mananara
# Processing Record 30 of Set 14 | nanzhang
# Processing Record 31 of Set 14 | sao felipe
# Processing Record 32 of Set 14 | ardakan
# Processing Record 33 of Set 14 | comodoro rivadavia
# Processing Record 34 of Set 14 | beaverlodge
# Processing Record 35 of Set 14 | jaisalmer
# Processing Record 36 of Set 14 | havelock
# Processing Record 37 of Set 14 | mutsamudu
# City not found. Skipping...
# Processing Record 38 of Set 14 | omboue
# Processing Record 39 of Set 14 | belaya gora
# Processing Record 40 of Set 14 | daru
# Processing Record 41 of Set 14 | fare
# Processing Record 42 of Set 14 | zaraza
# Processing Record 43 of Set 14 | anapolis
# Processing Record 44 of Set 14 | mudanjiang
# Processing Record 45 of Set 14 | come
# Processing Record 46 of Set 14 | westport
# Processing Record 47 of Set 14 | high level
# Processing Record 48 of Set 14 | kabo
# Processing Record 49 of Set 14 | karasjok
# Processing Record 50 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 1 of Set 15 | arman
# Processing Record 2 of Set 15 | zaozerne
# Processing Record 3 of Set 15 | nisia floresta
# Processing Record 4 of Set 15 | aasiaat
# Processing Record 5 of Set 15 | armash
# Processing Record 6 of Set 15 | arima
# Processing Record 7 of Set 15 | kawalu
# Processing Record 8 of Set 15 | mulege
# Processing Record 9 of Set 15 | erzin
# Processing Record 10 of Set 15 | maningrida
# Processing Record 11 of Set 15 | aklavik
# Processing Record 12 of Set 15 | bekhtery
# Processing Record 13 of Set 15 | shingu
# Processing Record 14 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 15 of Set 15 | vyshkov
# Processing Record 16 of Set 15 | dhenkanal
# Processing Record 17 of Set 15 | ayr
# Processing Record 18 of Set 15 | srednekolymsk
# Processing Record 19 of Set 15 | pljevlja
# Processing Record 20 of Set 15 | holland
# Processing Record 21 of Set 15 | aykhal
# Processing Record 22 of Set 15 | matara
# Processing Record 23 of Set 15 | bentiu
# Processing Record 24 of Set 15 | cardston
# Processing Record 25 of Set 15 | utiel
# Processing Record 26 of Set 15 | ust-nera
# Processing Record 27 of Set 15 | saint-joseph
# Processing Record 28 of Set 15 | santa luzia
# Processing Record 29 of Set 15 | simbahan
# Processing Record 30 of Set 15 | general roca
# Processing Record 31 of Set 15 | cayenne
# Processing Record 32 of Set 15 | marsh harbour
# Processing Record 33 of Set 15 | monrovia
# Processing Record 34 of Set 15 | grand baie
# Processing Record 35 of Set 15 | pimentel
# Processing Record 36 of Set 15 | maykor
# Processing Record 37 of Set 15 | bogale
# Processing Record 38 of Set 15 | hanzhong
# Processing Record 39 of Set 15 | male
# Processing Record 40 of Set 15 | betamcherla
# Processing Record 41 of Set 15 | tsienyane
# City not found. Skipping...
# Processing Record 42 of Set 15 | aguie
# Processing Record 43 of Set 15 | bourail
# Processing Record 44 of Set 15 | jacareacanga
# Processing Record 45 of Set 15 | naryan-mar
# Processing Record 46 of Set 15 | santa comba
# Processing Record 47 of Set 15 | tara
# Processing Record 48 of Set 15 | nuuk
# Processing Record 49 of Set 15 | berlevag
# Processing Record 50 of Set 15 | kibala
# Processing Record 1 of Set 16 | ca mau
# Processing Record 2 of Set 16 | camocim
# Processing Record 3 of Set 16 | tagusao
# Processing Record 4 of Set 16 | excelsior springs
# Processing Record 5 of Set 16 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 16 | budogoshch
# Processing Record 7 of Set 16 | laguna
# Processing Record 8 of Set 16 | mandera
# Processing Record 9 of Set 16 | sungairaya
# Processing Record 10 of Set 16 | nemuro
# Processing Record 11 of Set 16 | kushmurun
# Processing Record 12 of Set 16 | mandalgovi
# Processing Record 13 of Set 16 | talaya
# Processing Record 14 of Set 16 | maldonado
# Processing Record 15 of Set 16 | harper
# Processing Record 16 of Set 16 | ginda
# Processing Record 17 of Set 16 | conceicao do araguaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(f'The Length of the city_data list: {len(city_data)}')
# Out:
# The Length of the city_data list: 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Puerto Ayora  -0.7393  -90.3518     80.56        90          66
# 1  La Roche-Sur-Yon  46.6667   -1.4333     50.32        87          75
# 2            Torbay  47.6666  -52.7314     37.27        79          75
# 3    Saint-Philippe -21.3585   55.7679     67.59        75          34
# 4           Ahipara -35.1667  173.1667     65.34        85         100
# 5            Mocuba -16.8392   36.9856     72.63        90          61
# 6           Mataura -46.1927  168.8643     58.48        57          99
# 7             Kapaa  22.0752 -159.3190     79.12        63          40
# 8            Faanui -16.4833 -151.7500     78.46        77          98
# 9         Busselton -33.6500  115.3333     53.47        86          43
#
#    Wind Speed Country Current Description                 Date
# 0        5.01      EC       broken clouds  2022-11-15 20:43:06
# 1        8.05      FR       broken clouds  2022-11-15 20:43:37
# 2       16.11      CA       broken clouds  2022-11-15 20:43:19
# 3        9.15      RE          light rain  2022-11-15 20:43:37
# 4        1.10      NZ     overcast clouds  2022-11-15 20:43:37
# 5        1.14      MZ       broken clouds  2022-11-15 20:43:38
# 6        2.48      NZ     overcast clouds  2022-11-15 20:40:20
# 7       12.66      US    scattered clouds  2022-11-15 20:43:38
# 8        1.36      PF          light rain  2022-11-15 20:43:38
# 9        7.92      AU    scattered clouds  2022-11-15 20:43:38

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat","Lng", "Max Temp", "Humidity","Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[ new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0      Puerto Ayora      EC  -0.7393  -90.3518     80.56        90
# 1  La Roche-Sur-Yon      FR  46.6667   -1.4333     50.32        87
# 2            Torbay      CA  47.6666  -52.7314     37.27        79
# 3    Saint-Philippe      RE -21.3585   55.7679     67.59        75
# 4           Ahipara      NZ -35.1667  173.1667     65.34        85
# 5            Mocuba      MZ -16.8392   36.9856     72.63        90
# 6           Mataura      NZ -46.1927  168.8643     58.48        57
# 7             Kapaa      US  22.0752 -159.3190     79.12        63
# 8            Faanui      PF -16.4833 -151.7500     78.46        77
# 9         Busselton      AU -33.6500  115.3333     53.47        86
#
#    Cloudiness  Wind Speed Current Description
# 0          66        5.01       broken clouds
# 1          75        8.05       broken clouds
# 2          75       16.11       broken clouds
# 3          34        9.15          light rain
# 4         100        1.10     overcast clouds
# 5          61        1.14       broken clouds
# 6          99        2.48     overcast clouds
# 7          40       12.66    scattered clouds
# 8          98        1.36          light rain
# 9          43        7.92    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
import csv

# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file,index_label="City_ID")
